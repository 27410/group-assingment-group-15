# %% [markdown]
# Memote report of our chosen model of E-co

# %%
# !memote report snapshot iML1515.xml --filename iML1515.html
# Out:
# The current solver interface glpk doesn't support setting the optimality tolerance.
# ============================= test session starts ==============================
# platform darwin -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0
# rootdir: /Users/baochi
# plugins: anyio-3.5.0
# collected 155 items / 1 skipped
#
# ../anaconda3/lib/python3.11/site-packages/memote/suite/tests/test_annotation.py . [  0%]
# ..FFFFFFFFF.FFFFF.FFFFFFFFFFFFFFF..FF..F...F....FFF.F..FF.FFF...         [ 41%]
# ../anaconda3/lib/python3.11/site-packages/memote/suite/tests/test_basic.py . [ 42%]
# .....F............F.FF                                                   [ 56%]
# ../anaconda3/lib/python3.11/site-packages/memote/suite/tests/test_biomass.py . [ 57%]
# ..F...F.....FF..FF                                                       [ 69%]
# ../anaconda3/lib/python3.11/site-packages/memote/suite/tests/test_consistency.py . [ 69%]
# ...
