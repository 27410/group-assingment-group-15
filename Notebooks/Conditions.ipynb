# %%
# %run model_01.ipynb

# %% [markdown]
# WHAT DA FUCK

# %%
from cobra.flux_analysis.phenotype_phase_plane import production_envelope

# %%
ppp_succ = production_envelope(model,
                    reactions=[model.reactions.EX_glc__D_e],
                    objective=model.reactions.DM_faee)

# %%
ppp_succ
# Out:
#    carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0    EX_glc__D_e           0.0                   0.0                 0.0
# 1    EX_glc__D_e           0.0                   0.0                 0.0
# 2    EX_glc__D_e           0.0                   0.0                 0.0
# 3    EX_glc__D_e           0.0                   0.0                 0.0
# 4    EX_glc__D_e           0.0                   0.0                 0.0
# 5    EX_glc__D_e           0.0                   0.0                 0.0
# 6    EX_glc__D_e           0.0                   0.0                 0.0
# 7    EX_glc__D_e           0.0                   0.0                 0.0
# 8    EX_glc__D_e           0.0                   0.0                 0.0
# 9    EX_glc__D_e           0.0                   0.0                 0.0
# 10   EX_glc__D_e           0.0                   0.0                 0.0
# 11   EX_glc__D_e           0.0                   0.0                 0.0
# ...

# %%
ppp_succ.plot(x='EX_glc__D_e', y='flux_maximum')
# Out:
# <Axes: xlabel='EX_glc__D_e'>

# %%
ppp_succ = production_envelope(model,
                    reactions=[model.reactions.EX_glc__D_e, model.reactions.EX_o2_e],
                    objective=model.reactions.DM_faee)

# %%
ppp_succ
# Out:
#     carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0     EX_glc__D_e           0.0                   0.0                 0.0
# 1     EX_glc__D_e           0.0                   0.0                 0.0
# 2     EX_glc__D_e           0.0                   0.0                 0.0
# 3     EX_glc__D_e           0.0                   0.0                 0.0
# 4     EX_glc__D_e           0.0                   0.0                 0.0
# ..            ...           ...                   ...                 ...
# 395   EX_glc__D_e           0.0                   0.0                 0.0
# 396   EX_glc__D_e           0.0                   0.0                 0.0
# 397   EX_glc__D_e           0.0                   0.0                 0.0
# 398   EX_glc__D_e           0.0                   0.0                 0.0
# 399   EX_glc__D_e           NaN                   NaN                 NaN
#
#      flux_maximum  carbon_yield_maximum  mass_yield_maximum  EX_glc__D_e  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('default')
# %matplotlib inline
anaerobic_data_faee = ppp_succ[ppp_succ['EX_o2_e']==0]
plt.plot(anaerobic_data_faee['EX_glc__D_e'], anaerobic_data_faee['flux_maximum'], label='FAEE production - Anaerobic conditions')
plt.xlabel('Glucose Uptake Rate')
plt.ylabel('Maximum FAEE Flux')
# Out:
# Text(0, 0.5, 'Maximum FAEE Flux')

# %%
ppp_o2 = production_envelope(model,
                    reactions=[model.reactions.EX_o2_e],
                    objective=model.reactions.DM_faee)

# %%
ppp_o2.EX_o2_e[ppp_o2.flux_maximum.idxmax()]
# Out:
# -244.73684210526358

# %%
ppp_o2.plot(x='EX_o2_e', y='flux_maximum')
# Out:
# <Axes: xlabel='EX_o2_e'>
